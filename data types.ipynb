# %% [markdown]
# # Explain about data typesy## pes
# Basic data t
# In programming, data type is an important concept.
#
# Variables can store data of different types, and different types can do different things.
#
# Python has the following data types built-in by default, in these categor
# ies:ypes
# In
# In
# t
# floo
# t
#
# ## int:
# Integer (int):
#
# Represents whole numbers without a fractional component. Examples: 5, -3, .It includes - infinity to + infinity including 0
#
# ## float:
# Represents real numbers with a fractional component, typically expressed in decimal notation.
#
# ## Boolean (bool):
# Represents truth values and can be either True or False. Typically used in conditional statements and logical operations.When there is 0 it is false and when there is any value it is true.
#
# ## complex:
# complex A complex number is of the form a + bj, where a is the real part and b is the imaginary part.
#
# s.
# compl
# ex
# bool

# %%
# int
a=100
b=-23
g=24
print(a,b,g)
# Out:
# 100 -23 24

# %%
print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'int'>

# %%
#float
a=33.44
df=23.2
print(a)
print(df)
print(type(a))
print(type(df))
# Out:
# 33.44
# 23.2
# <class 'float'>
# <class 'float'>

# %%
#bool
bool(2)
# Out:
# True

# %%
bool(0)
print(type(bool(0)))
# Out:
# <class 'bool'>

# %%
#complex
a=1+2j
b=-2-4j
print(a,b)
print(type(a))
# Out:
# (1+2j) (-2-4j)
# <class 'complex'>

# %% [markdown]
# # Advanced data types
# list
# tuple
# dict
# str
# set

# %% [markdown]
# # string
# ## what is a string
# A string is a sequence of characters enclosed within either single or double quotes. They can be used to represent text, numbers, symbols, or any combination of characters.
#
# ## Examples:
# my_string = "Hello, world!"
#
# another_string = 'This is a string with single quotes.'
#
# number_as_string = "12345"

# %%
str1="hello"
str2="world"
str3="there"
str4="is"
str5="problem"

result1=str1+str2
result2=str1+" "+str3
result3=str2+" "+str3
result4=str1+' '+str2+' '+str3
result5=str1+" "+str2+' '+str3+' '+str4+' '+str5
result6=str1*6
result7=str2*3
result8=str3*1
result9=str4*5
result10=str5*8
print(result1)
print(result2)
print(result3)
print(result4)
print(result5)
print(result6)
print(result7)
print(result8)
print(result9)
print(result10)
# Out:
# helloworld
# hello there
# world there
# hello world there
# hello world there is problem
# hellohellohellohellohellohello
# worldworldworld
# there
# isisisisis
# problemproblemproblemproblemproblemproblemproblemproblem

# %%
# f string:
name="ruthwik"
age=24
print(f"my name is {name} iam {age} old")
# Out:
# my name is ruthwik iam 24 old

# %% [markdown]
# # string methods

# %% [markdown]
# ### len(string): Returns the length of the string (number of characters).

# %%
text = "Hello,  world!"
print(len(text))
# Out:
# 14

# %% [markdown]
# ### string.upper(): Converts all characters in the string to uppercase.

# %%
text = "Hello, world!"
print(text.upper())
# Out:
# HELLO, WORLD!

# %% [markdown]
# ### string.lower(): Converts all characters in the string to lowercase.

# %%
text = "Hello, world!"
print(text.lower())
# Out:
# hello, world!

# %% [markdown]
# ### string.capitalize(): Converts the first character of the string to uppercase and the rest to lowercase.

# %%
text = "hello, worlD!"
print(text.capitalize())
# Out:
# Hello, world!

# %% [markdown]
# ### string.swapcase(): Swaps the case of all characters in the string (uppercase becomes lowercase and vice versa).

# %%
text = "Hello, world!"
print(text.swapcase())
# Out:
# hELLO, WORLD!

# %% [markdown]
# ### string.title(): Converts the first character of each word in the string to uppercase and the rest to lowercase.

# %%
text = "hello, worlD!"
print(text.title())
# Out:
# Hello, World!

# %% [markdown]
# ### string.find(substring): Returns the index of the first occurrence of the substring within the string. If the substring is not found, it returns -1.

# %%
text = "Hello, world ld!"
print(text.find("ld"))
# Out:
# 10

# %% [markdown]
# ### string.rfind(substring): Returns the index of the last occurrence of the substring within the string. If the substring is not found, it returns -1.

# %%
text = "Hello, world, world!"
print(text.rfind("world"))
# Out:
# 14

# %% [markdown]
# ### string.startswith(prefix): Checks if the string starts with the specified prefix. Returns True or False.

# %%
text = "Hello, world!"
print(text.startswith("Hello"))
# Out:
# True

# %%
text = "hello, world!"
print(text.startswith("Hello"))
# Out:
# False

# %% [markdown]
# ### string.endswith(suffix): Checks if the string ends with the specified suffix. Returns True or False.

# %%
text = "Hello, world!"
print(text.endswith("world!"))
# Out:
# True

# %% [markdown]
# ### string.count(substring): Counts the number of occurrences of the substring within the string.

# %%
text = "Hello, world, world!"
print(text.count("world"))
# Out:
# 2

# %% [markdown]
# ### string.replace(old, new): Replaces all occurrences of the old substring with the new substring.

# %%
text = "Hello, world!"
print(text.replace("world", "there"))
# Out:
# Hello, there!

# %% [markdown]
# ### string.strip(): Removes starting and ending whitespace characters from the string.

# %%
text = "   Hello, world!   "
print(text.strip())
# Out:
# Hello, world!

# %% [markdown]
# ### string.lstrip(): Removes starting whitespace characters from the string.

# %%
text = "   Hello, world!   "
print(text.lstrip())
# Out:
# Hello, world!

# %% [markdown]
# ### string.rstrip(): Removes ending whitespace characters from the string.

# %%
text = "   Hello, world!   "
print(text.rstrip())
# Out:
#    Hello, world!

# %% [markdown]
# ### string.join(iterable): Joins the elements of an iterable (e.g., a list or tuple) into a single string using the string as a separator.

# %%
words = ["Hello", "world","are you ok"]
print(" ".join(words))
# Out:
# Hello world are you ok

# %% [markdown]
# ### string.split(): Splits the string into a list of substrings based on whitespace characters.

# %%
text = "Hello,  ,world!"
print(text.split())
# Out:
# ['Hello,', ',world!']

# %% [markdown]
# ### string.splitlines(): Splits the string into a list of substrings based on newline characters.

# %%
text = "Hello\nworld\nword!"
print(text.splitlines())
# Out:
# ['Hello', 'world', 'word!']

# %% [markdown]
# ### string.isalpha(): Checks if all characters in the string are alphabetic.

# %%
text = "Hello"
print(text.isalpha())
# Out:
# True

# %%
num='123'
print(num.isalpha())
# Out:
# False

# %% [markdown]
# ### string.isdigit(): Checks if all characters in the string are digits.

# %%
text = "123"
print(text.isdigit())
# Out:
# True

# %% [markdown]
# ### string.isalnum(): Checks if all characters in the string are alphanumeric (alphabetic or numeric).

# %%
text = "Hello123"
print(text.isalnum())
# Out:
# True

# %% [markdown]
# ### string.isspace(): Checks if all characters in the string are whitespace.

# %%
text = "  "
print(text.isspace())
# Out:
# True
